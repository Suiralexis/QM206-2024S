# %% [markdown]
# <a href="https://colab.research.google.com/github/Suiralexis/QM206-2024S/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# SEMESTRAL DE QUÍMICA COMPUTACIONAL,ALEXIS SUIRA 4-828-1050

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf29be57-6861-44e1-be78-b86ba90d3730" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf29be57-6861-44e1-be78-b86ba90d3730">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Leer el archivo cargado
file_name = list(uploaded.keys())[0]
df = pd.read_csv(file_name)

# Corregir problemas en los datos
df.rename(columns={'Annual CO2 emissions (per capita)': 'Annual_CO2_emissions_per_capita'}, inplace=True)
df['Annual_CO2_emissions_per_capita'] = pd.to_numeric(df['Annual_CO2_emissions_per_capita'], errors='coerce')

# Análisis descriptivo básico
print("Resumen estadístico de los datos:")
print(df.describe())

# Visualización: Gráfico de barras
df['Entity'] = df['Entity'].str.strip()
emissions_mean = df.groupby('Entity')['Annual_CO2_emissions_per_capita'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
emissions_mean.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Entidades con Mayor Emisión Promedio de CO2 (Per Cápita)')
plt.xlabel('Entidad')
plt.ylabel('Emisiones Promedio (Toneladas)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Visualización: Gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['Annual_CO2_emissions_per_capita'], alpha=0.5, color='green')
plt.title('Emisiones de CO2 Per Cápita a lo Largo del Tiempo')
plt.xlabel('Año')
plt.ylabel('Emisiones Per Cápita (Toneladas)')
plt.grid()
plt.tight_layout()
plt.show()

# Visualización: Gráfico de pastel
top_entities = emissions_mean.head(5)
plt.figure(figsize=(8, 8))
top_entities.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['blue', 'orange', 'green', 'red', 'purple'])
plt.title('Participación de las 5 Entidades Principales en Emisiones Promedio')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# Resumen estadístico de los datos:
#                Year  Annual_CO2_emissions_per_capita
# count  26600.000000                     2.660000e+04
# mean    1949.096880                     2.182557e+07
# std       56.387496                     2.325755e+07
# min     1750.000000                     0.000000e+00
# 25%     1915.000000                     5.485310e+06
# 50%     1963.000000                     1.327592e+07
# 75%     1994.000000                     3.113626e+07
# max     2022.000000                     1.568619e+08

# %%
# Análisis descriptivo básico
print("Resumen estadístico de los datos:")
print(df.describe())

# Visualización: Gráfico de barras
df['Entity'] = df['Entity'].str.strip()  # Limpiar espacios en blanco de los nombres
emissions_mean = df.groupby('Entity')['Annual_CO2_emissions_per_capita'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
emissions_mean.head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Entidades con Mayor Emisión Promedio de CO2 (Per Cápita)')
plt.xlabel('Entidad')
plt.ylabel('Emisiones Promedio (Toneladas)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# Visualización: Gráfico de dispersión
plt.figure(figsize=(10, 6))
plt.scatter(df['Year'], df['Annual_CO2_emissions_per_capita'], alpha=0.5, color='green')
plt.title('Emisiones de CO2 Per Cápita a lo Largo del Tiempo')
plt.xlabel('Año')
plt.ylabel('Emisiones Per Cápita (Toneladas)')
plt.grid()
plt.show()

# Visualización: Gráfico de pastel
top_entities = emissions_mean.head(5)
top_entities.plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8), startangle=90, colormap='Pastel1')
plt.title('Participación de las 5 Entidades Principales en Emisiones Promedio')
plt.ylabel('')
plt.show()
# Out:
# Resumen estadístico de los datos:
#                Year  Annual_CO2_emissions_per_capita
# count  26600.000000                     2.660000e+04
# mean    1949.096880                     2.182557e+07
# std       56.387496                     2.325755e+07
# min     1750.000000                     0.000000e+00
# 25%     1915.000000                     5.485310e+06
# 50%     1963.000000                     1.327592e+07
# 75%     1994.000000                     3.113626e+07
# max     2022.000000                     1.568619e+08

# %%
import matplotlib.pyplot as plt

# Lista de países de América Central
central_america = [
    "Belize", "Costa Rica", "El Salvador", "Guatemala", "Honduras", "Nicaragua", "Panama"
]

# Filtrar datos de América Central
central_america_df = df[df['Entity'].isin(central_america)]

# 1. Gráfico de Barras: Emisiones promedio por país en América Central
emissions_by_country = central_america_df.groupby('Entity')['Annual_CO2_emissions_per_capita'].mean().sort_values()

plt.figure(figsize=(10, 6))
emissions_by_country.plot(kind='bar', color='teal')
plt.title('Emisiones Promedio de CO2 Per Cápita en América Central')
plt.xlabel('País')
plt.ylabel('Emisiones Promedio (Toneladas)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# 2. Gráfico de Dispersión: Emisiones a lo Largo del Tiempo en América Central
plt.figure(figsize=(10, 6))
for country in central_america:
    subset = central_america_df[central_america_df['Entity'] == country]
    plt.scatter(subset['Year'], subset['Annual_CO2_emissions_per_capita'], alpha=0.6, label=country)

plt.title('Emisiones de CO2 Per Cápita en América Central a lo Largo del Tiempo')
plt.xlabel('Año')
plt.ylabel('Emisiones Per Cápita (Toneladas)')
plt.legend(title='País')
plt.grid()
plt.show()

# 3. Gráfico de Línea: Tendencia de Emisiones Totales en América Central
emissions_by_year = central_america_df.groupby('Year')['Annual_CO2_emissions_per_capita'].sum()

plt.figure(figsize=(10, 6))
plt.plot(emissions_by_year.index, emissions_by_year.values, marker='o', linestyle='-', color='purple')
plt.title('Tendencia de Emisiones Totales de CO2 Per Cápita en América Central')
plt.xlabel('Año')
plt.ylabel('Emisiones Totales (Toneladas)')
plt.grid()
plt.show()

# %%
# Versión 1 (Yo): Análisis del inventario de gas natural en Google Colab

import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Subir archivo localmente
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# Cargar el archivo
df_gas_local = pd.read_csv(file_name)

# Convertir REF_DATE a formato datetime
df_gas_local['REF_DATE'] = pd.to_datetime(df_gas_local['REF_DATE'])

# Filtrar datos con unidad de medida en Gigajoules
df_gigajoules = df_gas_local[df_gas_local['Statistics'] == 'Gigajoules']

# Promedio mensual del inventario de apertura
monthly_opening_inventory = df_gigajoules[df_gigajoules['Storage'] == 'Opening inventory'].groupby('REF_DATE')['VALUE'].mean()

# Gráfico de línea: Promedio del inventario de apertura
plt.figure(figsize=(12, 6))
plt.plot(monthly_opening_inventory.index, monthly_opening_inventory.values, label='Inventario de Apertura', color='blue')
plt.title('Promedio del Inventario de Apertura en Gigajoules (2016-2024)')
plt.xlabel('Fecha')
plt.ylabel('Gigajoules')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# Cambios acumulativos del inventario por año
yearly_inventory_change = df_gigajoules[df_gigajoules['Storage'] == 'Inventory change'].groupby(df_gigajoules['REF_DATE'].dt.year)['VALUE'].sum()

# Gráfico de barras: Cambios acumulativos del inventario
plt.figure(figsize=(10, 6))
yearly_inventory_change.plot(kind='bar', color='orange', alpha=0.7)
plt.title('Cambio Acumulativo del Inventario por Año (Gigajoules)')
plt.xlabel('Año')
plt.ylabel('Cambio Acumulado (Gigajoules)')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# Inventario de cierre promedio por año
closing_inventory_by_year = df_gigajoules[df_gigajoules['Storage'] == 'Closing inventory'].groupby(df_gigajoules['REF_DATE'].dt.year)['VALUE'].mean()

# Gráfico de línea: Inventario de cierre promedio por año
plt.figure(figsize=(12, 6))
plt.plot(closing_inventory_by_year.index, closing_inventory_by_year.values, marker='o', linestyle='--', color='green', label='Inventario de Cierre')
plt.title('Inventario de Cierre Promedio por Año (Gigajoules)')
plt.xlabel('Año')
plt.ylabel('Gigajoules')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-bc30c925-913e-4705-93a4-092b817c99d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc30c925-913e-4705-93a4-092b817c99d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Discusión de las gráficas:

#

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

# Subir el archivo localmente
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# Cargar el archivo
df = pd.read_csv(file_name)

# Relación entre el tamaño del motor y las emisiones de CO2
plt.figure(figsize=(10, 6))
plt.scatter(df['Engine Size(L)'], df['CO2 Emissions(g/km)'], alpha=0.7, color='blue')
plt.title('Relación entre el Tamaño del Motor y las Emisiones de CO2')
plt.xlabel('Tamaño del Motor (L)')
plt.ylabel('Emisiones de CO2 (g/km)')
plt.grid()
plt.tight_layout()
plt.show()

# Emisiones promedio por clase de vehículo
average_emissions_vehicle_class = df.groupby('Vehicle Class')['CO2 Emissions(g/km)'].mean().sort_values()

plt.figure(figsize=(12, 6))
average_emissions_vehicle_class.plot(kind='bar', color='green', alpha=0.8)
plt.title('Emisiones Promedio de CO2 por Clase de Vehículo')
plt.xlabel('Clase de Vehículo')
plt.ylabel('Promedio de Emisiones (g/km)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Impacto del tipo de combustible en las emisiones de CO2
average_emissions_fuel_type = df.groupby('Fuel Type')['CO2 Emissions(g/km)'].mean().sort_values()

plt.figure(figsize=(10, 6))
average_emissions_fuel_type.plot(kind='bar', color='orange', alpha=0.8)
plt.title('Impacto del Tipo de Combustible en las Emisiones de CO2')
plt.xlabel('Tipo de Combustible')
plt.ylabel('Promedio de Emisiones (g/km)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-2a427129-2ff0-4c78-8696-a8a66bc672f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2a427129-2ff0-4c78-8696-a8a66bc672f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

plt.figure(figsize=(10, 6))
plt.scatter(df['Engine Size(L)'], df['CO2 Emissions(g/km)'], alpha=0.7, color='blue')
plt.title('Relación entre el Tamaño del Motor y las Emisiones de CO2')
plt.xlabel('Tamaño del Motor (L)')
plt.ylabel('Emisiones de CO2 (g/km)')
plt.grid()
plt.tight_layout()
plt.show()

average_emissions_vehicle_class = df.groupby('Vehicle Class')['CO2 Emissions(g/km)'].mean().sort_values()

plt.figure(figsize=(12, 6))
average_emissions_vehicle_class.plot(kind='bar', color='green', alpha=0.8)
plt.title('Emisiones Promedio de CO2 por Clase de Vehículo')
plt.xlabel('Clase de Vehículo')
plt.ylabel('Promedio de Emisiones (g/km)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

average_emissions_fuel_type = df.groupby('Fuel Type')['CO2 Emissions(g/km)'].mean().sort_values()

plt.figure(figsize=(10, 6))
average_emissions_fuel_type.plot(kind='bar', color='orange', alpha=0.8)
plt.title('Impacto del Tipo de Combustible en las Emisiones de CO2')
plt.xlabel('Tipo de Combustible')
plt.ylabel('Promedio de Emisiones (g/km)')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-d2b8d79c-a816-45f9-b53a-90fe6a8fcf60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2b8d79c-a816-45f9-b53a-90fe6a8fcf60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Discusión de las gráficas:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

exceed_mcl = df[df['Result'] > df['MCL']].groupby('School')['Result'].count()

plt.figure(figsize=(12, 6))
exceed_mcl.plot(kind='bar', color='red', alpha=0.8)
plt.title('Cantidad de Muestras que Exceden el Nivel Máximo de Contaminante (MCL)')
plt.xlabel('Escuela')
plt.ylabel('Número de Muestras')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df['Result'], bins=20, color='blue', alpha=0.7)
plt.title('Distribución de los Niveles de Plomo en las Muestras')
plt.xlabel('Concentración de Plomo (mg/L)')
plt.ylabel('Frecuencia')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

consumption_points = df['Consumption Point'].value_counts()

plt.figure(figsize=(8, 6))
consumption_points.plot(kind='pie', autopct='%1.1f%%', startangle=90, colormap='Pastel1')
plt.title('Proporción de Muestras por Punto de Consumo')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-3ec9e017-a1f4-4c6b-ab1f-f58ecaa4095c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ec9e017-a1f4-4c6b-ab1f-f58ecaa4095c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

exceed_mcl = df[df['Result'] > df['MCL']].groupby('School')['Result'].count()

plt.figure(figsize=(12, 6))
exceed_mcl.plot(kind='bar', color='red', alpha=0.8)
plt.title('Cantidad de Muestras que Exceden el Nivel Máximo de Contaminante (MCL)')
plt.xlabel('Escuela')
plt.ylabel('Número de Muestras')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df['Result'], bins=50, range=(0, 0.5), color='blue', alpha=0.7)
plt.title('Distribución de los Niveles de Plomo en las Muestras (Rango Ajustado)')
plt.xlabel('Concentración de Plomo (mg/L)')
plt.ylabel('Frecuencia')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

consumption_points = df['Consumption Point'].value_counts()

plt.figure(figsize=(8, 6))
consumption_points.plot(kind='pie', autopct='%1.1f%%', startangle=90, colors=['skyblue', 'orange'])
plt.title('Proporción de Muestras por Punto de Consumo')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-b9b6e79b-2b9a-4a2b-babe-a35e17459179" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b9b6e79b-2b9a-4a2b-babe-a35e17459179">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files

uploaded = files.upload()
file_name = list(uploaded.keys())[0]

df = pd.read_csv(file_name)

plt.figure(figsize=(10, 6))
plt.scatter(df['PM2.5'], df['PM10'], alpha=0.7, color='blue')
plt.title('Relación entre PM2.5 y PM10')
plt.xlabel('PM2.5 (µg/m³)')
plt.ylabel('PM10 (µg/m³)')
plt.grid()
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.scatter(df['Proximity_to_Industrial_Areas'], df['PM2.5'], alpha=0.7, color='green')
plt.title('Influencia de la Proximidad a Zonas Industriales en PM2.5')
plt.xlabel('Proximidad a Zonas Industriales (km)')
plt.ylabel('PM2.5 (µg/m³)')
plt.grid()
plt.tight_layout()
plt.show()

air_quality_distribution = df['Air Quality'].value_counts()

plt.figure(figsize=(8, 6))
air_quality_distribution.plot(kind='bar', color='orange', alpha=0.8)
plt.title('Distribución de la Calidad del Aire')
plt.xlabel('Categoría de Calidad del Aire')
plt.ylabel('Número de Registros')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#      <input type="file" id="files-aea44055-3920-442a-ab96-bd1620da6041" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aea44055-3920-442a-ab96-bd1620da6041">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
